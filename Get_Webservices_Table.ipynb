# %%
import pandas as pd
from web_services_list import *

# %%
srcs = select_all_connections()
odf = pd.DataFrame(srcs, columns=['Connection Type', 'Name', '', '', '', 'Source', '', '', ''])
odf = odf[['Name', 'Connection Type', 'Source']]
odf
# Out:
#                                        Name                  Connection Type  \
# 0                               Google Maps                  connections-xyz
# 1                          Google Satellite                  connections-xyz
# 2                            Google Terrain                  connections-xyz
# 3                     Google Terrain Hybrid                  connections-xyz
# 4                   Google Satellite Hybrid                  connections-xyz
# ..                                      ...                              ...
# 96              NOAA Global Geoscience Data  connections-arcgisfeatureserver
# 97   North West Territories Geoscience Data  connections-arcgisfeatureserver
# 98                 NZ - Minerals Map Layers  connections-arcgisfeatureserver
# 99                     Peru Geoscience Data  connections-arcgisfeatureserver
# 100         Slovakia Geological Survey Data  connections-arcgisfeatureserver
#
# ...

# %%
odf.to_html('readme_table')
